# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated, List
import operator
from langgraph.checkpoint.sqlite import SqliteSaver
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, AIMessage, ChatMessage

memory = SqliteSaver.from_conn_string(":memory:")

# %%
class AgentState(TypedDict):
    task: str
    plan: str
    draft: str
    critique: str
    content: List[str]
    revision_number: int
    max_revisions: int

# %%
from langchain_openai import ChatOpenAI
model = ChatOpenAI(model="gpt-3.5-turbo", temperature=0)

# %%
PLAN_PROMPT = """You are an expert writer tasked with writing a high level outline of an essay. \
Write such an outline for the user provided topic. Give an outline of the essay along with any relevant notes \
or instructions for the sections."""

# %%
WRITER_PROMPT = """You are an essay assistant tasked with writing excellent 5-paragraph essays.\
Generate the best essay possible for the user's request and the initial outline. \
If the user provides critique, respond with a revised version of your previous attempts. \
Utilize all the information below as needed: 

------

{content}"""

# %%
REFLECTION_PROMPT = """You are a teacher grading an essay submission. \
Generate critique and recommendations for the user's submission. \
Provide detailed recommendations, including requests for length, depth, style, etc."""

# %%
RESEARCH_PLAN_PROMPT = """You are a researcher charged with providing information that can \
be used when writing the following essay. Generate a list of search queries that will gather \
any relevant information. Only generate 3 queries max."""

# %%
RESEARCH_CRITIQUE_PROMPT = """You are a researcher charged with providing information that can \
be used when making any requested revisions (as outlined below). \
Generate a list of search queries that will gather any relevant information. Only generate 3 queries max."""

# %%
from langchain_core.pydantic_v1 import BaseModel

class Queries(BaseModel):
    queries: List[str]

# %%
from tavily import TavilyClient
import os
tavily = TavilyClient(api_key=os.environ["TAVILY_API_KEY"])

# %%
def plan_node(state: AgentState):
    messages = [
        SystemMessage(content=PLAN_PROMPT), 
        HumanMessage(content=state['task'])
    ]
    response = model.invoke(messages)
    return {"plan": response.content}

# %%
def research_plan_node(state: AgentState):
    queries = model.with_structured_output(Queries).invoke([
        SystemMessage(content=RESEARCH_PLAN_PROMPT),
        HumanMessage(content=state['task'])
    ])
    content = state['content'] or []
    for q in queries.queries:
        response = tavily.search(query=q, max_results=2)
        for r in response['results']:
            content.append(r['content'])
    return {"content": content}

# %%
def generation_node(state: AgentState):
    content = "\n\n".join(state['content'] or [])
    user_message = HumanMessage(
        content=f"{state['task']}\n\nHere is my plan:\n\n{state['plan']}")
    messages = [
        SystemMessage(
            content=WRITER_PROMPT.format(content=content)
        ),
        user_message
        ]
    response = model.invoke(messages)
    return {
        "draft": response.content, 
        "revision_number": state.get("revision_number", 1) + 1
    }

# %%
def reflection_node(state: AgentState):
    messages = [
        SystemMessage(content=REFLECTION_PROMPT), 
        HumanMessage(content=state['draft'])
    ]
    response = model.invoke(messages)
    return {"critique": response.content}

# %%
def research_critique_node(state: AgentState):
    queries = model.with_structured_output(Queries).invoke([
        SystemMessage(content=RESEARCH_CRITIQUE_PROMPT),
        HumanMessage(content=state['critique'])
    ])
    content = state['content'] or []
    for q in queries.queries:
        response = tavily.search(query=q, max_results=2)
        for r in response['results']:
            content.append(r['content'])
    return {"content": content}

# %%
def should_continue(state):
    if state["revision_number"] > state["max_revisions"]:
        return END
    return "reflect"

# %%
builder = StateGraph(AgentState)

# %%
builder.add_node("planner", plan_node)
builder.add_node("generate", generation_node)
builder.add_node("reflect", reflection_node)
builder.add_node("research_plan", research_plan_node)
builder.add_node("research_critique", research_critique_node)

# %%
builder.set_entry_point("planner")

# %%
builder.add_conditional_edges(
    "generate", 
    should_continue, 
    {END: END, "reflect": "reflect"}
)

# %%
builder.add_edge("planner", "research_plan")
builder.add_edge("research_plan", "generate")

builder.add_edge("reflect", "research_critique")
builder.add_edge("research_critique", "generate")

# %%
graph = builder.compile(checkpointer=memory)

# %%
from IPython.display import Image

Image(graph.get_graph().draw_png())

# %%
thread = {"configurable": {"thread_id": "1"}}
for s in graph.stream({
    'task': "what is the difference between langchain and langsmith",
    "max_revisions": 2,
    "revision_number": 1,
}, thread):
    print(s)
# Out:
# {'planner': {'plan': 'I. Introduction\n    A. Brief overview of Langchain and Langsmith\n    B. Thesis statement: Exploring the differences between Langchain and Langsmith\n\nII. Langchain\n    A. Definition and purpose\n    B. Key features and characteristics\n    C. Use cases and applications\n    D. Advantages and limitations\n\nIII. Langsmith\n    A. Definition and purpose\n    B. Key features and characteristics\n    C. Use cases and applications\n    D. Advantages and limitations\n\nIV. Contrasting Langchain and Langsmith\n    A. Technical differences\n    B. Functional differences\n    C. Comparative analysis of strengths and weaknesses\n    D. Potential synergies and collaborations\n\nV. Conclusion\n    A. Recap of main points\n    B. Implications of understanding the differences between Langchain and Langsmith\n    C. Future outlook and developments in the field of language technology\n\nNotes:\n- Ensure a clear and concise explanation of Langchain and Langsmith in the introduction.\n- Provide specific examples and case studies to illustrate the differences between the two technologies.\n- Use comparative analysis to highlight the unique features and benefits of each technology.\n- Conclude with insights on the significance of these technologies in the evolving landscape of language technology.'}}
# {'research_plan': {'content': ['Langchain vs Langsmith: Unpacking the AI Language Model Showdown\nOverview of Langchain and Langsmith\nLangchain is a versatile open-source framework that enables you to build applications utilizing large language models (LLM) like GPT-3. Check out our free WhatsApp channel to stay educated on LLM developments:\nJoin the Finxter Academy and unlock access to premium courses 👑 to certify your skills in exponential technologies and programming.\n Frequently Asked Questions\nWhether you’re trying to figure out which tool fits your needs or you’re just getting started with language model automation, these FAQs will help shed light on the common curiosities about Langchain and LangSmith.\n The best way to find out is to reach out to them through the LangSmith Walkthrough page or to inquire about access directly through their support channels.\n Here’s how you might start a simple Langchain project in Python:\nTo integrate LangSmith, you could write something like this:\nYou’re not limited to Python, though.', "LangSmith Cookbook: Real-world Lang Smith Examples\nThe LangSmith Cookbook is not just a compilation of code snippets; it's a goldmine of hands-on examples designed to inspire and assist you in your projects. On This Page\nLangSmith: Best Way to Test LLMs and AI Application\nPublished on 12/17/2023\nIf you're in the world of Language Learning Models (LLMs), you've probably heard of LangSmith. How to Download Feedback and Examples (opens in a new tab): Export predictions, evaluation results, and other information to add to your reports programmatically.\n This article is your one-stop guide to understanding LangSmith, a platform that offers a plethora of features for debugging, testing, evaluating, and monitoring LLM applications.\n How do I get access to LangSmith?\nTo get access to LangSmith, you'll need to sign up for an account on their website.", "Introduction. LangChain is a framework for developing applications powered by large language models (LLMs).. LangChain simplifies every stage of the LLM application lifecycle: Development: Build your applications using LangChain's open-source building blocks, components, and third-party integrations.Use LangGraph to build stateful agents with first-class streaming and human-in-the-loop support.", 'Join Discord\nContribute on GitHub\n5.3M\nMonthly Downloads\n67k\nGithub Stars\n1800+\nContributors\n34k+\nApps Powered\nReady to build?\nGo To Docs\nGo To Docs\nGo To Docs\nContact Sales\nContact Sales\nContact Sales\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter Chatbots\nQ&A Over Docs\nSummarization\nCopilots\nWorkflow Automation\nDocument Analysis\nCustom Search\nHarness the power–and wrangle the complexity– of LLMs\nGet from proof-of-concept to production on one platform\nRely on a set of tools built especially for non-deterministic models\nLeverage new cognitive architectures and battle-tested orchestration\nThanks to our contributors and partners for making LangChain awesome\nWhen you build with LangChain, you build alongside a community of developers advancing the frontier of what’s possible with LLMs.\n 🦜🔗 LangChain\nLangSmith\nLangServe\nAgents\nRetrieval\nEvaluation\nBlog\nDocs\n🦜🔗 LangChain\n🦜🔗 LangChain\nLangChain Expression Language makes it easy to create custom chains.\n Go To Docs\nGo To Docs\nGo To Docs\nConta ...
# {'generate': {'draft': "**Title: Langchain vs Langsmith: Contrasting Two Leading AI Language Models**\n\nI. Introduction\nIn the realm of AI language models, Langchain and Langsmith stand out as prominent frameworks that facilitate the development and deployment of applications powered by large language models (LLMs). While both serve a similar purpose, they possess distinct features and functionalities that set them apart. This essay delves into the disparities between Langchain and Langsmith to provide a comprehensive understanding of their unique characteristics and applications.\n\nII. Langchain\nLangchain is an open-source framework designed to streamline the creation of applications utilizing LLMs like GPT-3. Its key features include a robust set of building blocks, components, and third-party integrations that simplify the development process. Langchain offers versatility in building stateful agents with streaming capabilities and human-in-the-loop support. Common use cases for Langchain span from chatbots to document analysis, showcasing its adaptability. While Langchain empowers developers with a wide array of tools, it may have limitations in terms of scalability for extremely large projects.\n\nIII. Langsmith\nOn the other hand, Langsmith is a unified DevOps platform tailored for the comprehensive lifecycle management of LLM applications. It excels in facilitating collaboration, testing, deployment, and monitoring of intelligent agents built on various LLM frameworks. Langsmith's strength lies in its seamless integration with Langchain, offering developers a holistic environment for debugging, testing, and evaluating their applications. Its versatility extends to different stages of application development, making it a valuable asset for teams working on complex language model projects.\n\nIV. Contrasting Langchain and Langsmith\nWhen comparing Langchain and Langsmith, technical disparities become apparent. Langchain focuses on simplifying the development process with its open-source building blocks, while Langsmith emphasizes the operational aspects of managing LLM applications. Functionally, Langchain is more geared towards application development, whereas Langsmith caters to the operational and monitoring aspects of LLM projects. A comparative analysis reveals that Langchain excels in flexibility and customization, while Langsmith shines in providing a structured environment for collaboration and monitoring. Despite their differences, the potential synergies between Langchain and Langsmith could lead to enhanced capabilities in both development and operational aspects of LLM applications.\n\nV. Conclusion\nIn conclusion, understanding the nuances between Langchain and Langsmith is crucial for developers and organizations navigating the landscape of AI language models. By recognizing the strengths and limitations of each framework, stakeholders can make informed decisions on which platform best suits their needs. The evolving field of language technology will continue to benefit from the advancements offered by Langchain and Langsmith, paving the way for innovative applications and solutions in the realm of AI-driven language processing.", 'revision_number': 2}}
# {'reflect': {'critique': '**Overall Feedback:**\n- The essay provides a clear and structured comparison between Langchain and Langsmith, highlighting their key features and differences effectively.\n- The introduction sets the stage well by outlining the purpose of the essay, and the conclusion effectively summarizes the key points discussed.\n- The content is informative and well-organized, making it easy for readers to understand the distinctions between the two frameworks.\n\n**Areas for Improvement:**\n1. **Depth and Detail:** While the essay provides a good overview of Langchain and Langsmith, consider adding more specific examples or case studies to illustrate how each framework is used in real-world scenarios. This will enhance the depth of your analysis and provide a more comprehensive understanding of their applications.\n   \n2. **Technical Analysis:** To further enrich your comparison, delve deeper into the technical aspects of Langchain and Langsmith. Discuss specific functionalities, algorithms, or performance metrics that differentiate the two frameworks. This will appeal to a more technically inclined audience and provide a more nuanced evaluation.\n\n3. **Scalability Discussion:** You briefly mention scalability as a potential limitation of Langchain for extremely large projects. Expand on this point by exploring how each framework handles scalability challenges, resource management, and performance optimization. This will add depth to your analysis and address a critical aspect of AI model deployment.\n\n4. **User Experience and Interface:** Consider discussing the user experience and interface design of Langchain and Langsmith. How intuitive are these platforms for developers? Do they offer user-friendly features or tools that enhance productivity? Evaluating the usability aspects can provide valuable insights for readers considering these frameworks for their projects.\n\n5. **Future Prospects:** Touch upon the future prospects of Langchain and Langsmith. Are there any upcoming updates, features, or trends that could impact their relevance in the AI language model landscape? Speculating on the potential evolution of these frameworks can add a forward-looking perspective to your analysis.\n\n**Additional Recommendations:**\n- **Length:** Consider expanding on each section to provide more in-depth analysis and examples. Aim for a more detailed exploration of the features, functionalities, and implications of Langchain and Langsmith.\n  \n- **Citations:** If you reference specific sources, frameworks, or studies in your essay, ensure to include citations to support your claims and provide credibility to your analysis.\n  \n- **Visual Aids:** Incorporating visual aids such as diagrams, charts, or tables can enhance the clarity of your comparison. Visual representations can help readers grasp complex concepts more easily and reinforce your arguments effectively.\n\n- **Style and Tone:** Maintain a formal and objective tone throughout the essay. Avoid subjective language and ensure that your analysis remains impartial and fact-based to strengthen the credibility of your evaluation.\n\nBy incorporating these recommendations and expanding on the existing content, you can enrich your comparison of Langchain and Langsmith, providing readers with a more comprehensive and insightful analysis of these leading AI language models.'}}
# {'research_critique': {'content': ['Langchain vs Langsmith: Unpacking the AI Language Model Showdown\nOverview of Langchain and Langsmith\nLangchain is a versatile open-source framework that enables you to build applications utilizing large language models (LLM) like GPT-3. Check out our free WhatsApp channel to stay educated on LLM developments:\nJoin the Finxter Academy and unlock access to premium courses 👑 to certify your skills in exponential technologies and programming.\n Frequently Asked Questions\nWhether you’re trying to figure out which tool fits your needs or you’re just getting started with language model automation, these FAQs will help shed light on the common curiosities about Langchain and LangSmith.\n The best way to find out is to reach out to them through the LangSmith Walkthrough page or to inquire about access directly through their support channels.\n Here’s how you might start a simple Langchain project in Python:\nTo integrate LangSmith, you could write something like this:\nYou’re not limited to Python, though.', "LangSmith Cookbook: Real-world Lang Smith Examples\nThe LangSmith Cookbook is not just a compilation of code snippets; it's a goldmine of hands-on examples designed to inspire and assist you in your projects. On This Page\nLangSmith: Best Way to Test LLMs and AI Application\nPublished on 12/17/2023\nIf you're in the world of Language Learning Models (LLMs), you've probably heard of LangSmith. How to Download Feedback and Examples (opens in a new tab): Export predictions, evaluation results, and other information to add to your reports programmatically.\n This article is your one-stop guide to understanding LangSmith, a platform that offers a plethora of features for debugging, testing, evaluating, and monitoring LLM applications.\n How do I get access to LangSmith?\nTo get access to LangSmith, you'll need to sign up for an account on their website.", "Introduction. LangChain is a framework for developing applications powered by large language models (LLMs).. LangChain simplifies every stage of the LLM application lifecycle: Development: Build your applications using LangChain's open-source building blocks, components, and third-party integrations.Use LangGraph to build stateful agents with first-class streaming and human-in-the-loop support.", 'Join Discord\nContribute on GitHub\n5.3M\nMonthly Downloads\n67k\nGithub Stars\n1800+\nContributors\n34k+\nApps Powered\nReady to build?\nGo To Docs\nGo To Docs\nGo To Docs\nContact Sales\nContact Sales\nContact Sales\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter Chatbots\nQ&A Over Docs\nSummarization\nCopilots\nWorkflow Automation\nDocument Analysis\nCustom Search\nHarness the power–and wrangle the complexity– of LLMs\nGet from proof-of-concept to production on one platform\nRely on a set of tools built especially for non-deterministic models\nLeverage new cognitive architectures and battle-tested orchestration\nThanks to our contributors and partners for making LangChain awesome\nWhen you build with LangChain, you build alongside a community of developers advancing the frontier of what’s possible with LLMs.\n 🦜🔗 LangChain\nLangSmith\nLangServe\nAgents\nRetrieval\nEvaluation\nBlog\nDocs\n🦜🔗 LangChain\n🦜🔗 LangChain\nLangChain Expression Language makes it easy to create custom chains.\n Go To Docs\nGo To Docs\nGo To Docs\nC ...
# {'generate': {'draft': "**Title: Langchain vs Langsmith: Contrasting Two Leading AI Language Model Frameworks**\n\nI. Introduction\nIn the realm of AI language model frameworks, Langchain and Langsmith stand out as prominent tools for developing applications powered by large language models (LLMs). While both serve a similar purpose, they possess distinct features and functionalities that cater to different aspects of language model automation.\n\nII. Langchain\nLangchain is an open-source framework designed to simplify the development of applications utilizing LLMs like GPT-3. Its key features include a versatile set of building blocks, components, and third-party integrations, making it a go-to choice for developers seeking to harness the power of language models. Langchain offers a range of applications, from chatbots to document analysis, and provides a flexible toolkit for creating context-aware, reasoning applications. However, its limitations may lie in the complexity of integrating with certain environments and the learning curve associated with its advanced features.\n\nIII. Langsmith\nOn the other hand, Langsmith is a unified DevOps platform tailored for the entire lifecycle of LLM applications. It excels in facilitating collaboration, testing, deployment, and monitoring of language models, offering a comprehensive solution for developers. Langsmith's focus on debugging, testing, and evaluating chains and intelligent agents sets it apart as a tool dedicated to ensuring the quality and efficiency of LLM applications. While Langsmith streamlines the development process, it may have constraints in terms of customization and adaptability to specific project requirements.\n\nIV. Contrasting Langchain and Langsmith\nWhen comparing Langchain and Langsmith, technical differences become apparent. Langchain emphasizes building applications with a community-driven approach, leveraging a wide range of tools and integrations. In contrast, Langsmith prioritizes the operational aspects of LLM applications, providing a robust platform for deployment and monitoring. Functionally, Langchain shines in its flexibility and abstraction layers, allowing for diverse applications, while Langsmith excels in its debugging and testing capabilities, ensuring the reliability of LLM applications. A comparative analysis reveals that Langchain's strength lies in its versatility, while Langsmith's forte is in its operational efficiency.\n\nV. Conclusion\nUnderstanding the disparities between Langchain and Langsmith is crucial for developers and organizations navigating the landscape of language technology. While Langchain offers a broad spectrum of applications and tools, Langsmith provides a specialized platform for ensuring the quality and scalability of LLM applications. The synergy between these frameworks presents opportunities for collaboration and innovation in the field of AI language models, shaping the future of language technology with enhanced capabilities and efficiency.", 'revision_number': 3}}
